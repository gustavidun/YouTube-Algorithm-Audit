# %%
import pandas as pd
from pathlib import Path
import sys

ROOT = Path("../")
sys.path.append(str(ROOT / "src"))

import puppet

# %%
path = "../data/puppets/test.pkl"
df = pd.read_pickle(path)
df.iloc[1]["topics"]
# Out:
#   puppet_id puppet_state  puppet_slant puppet_cond  depth     video_id  \
# 0      test     training      0.000000      (0, 1)      1  WIl1nVudjFo
# 1      test     drifting      0.000000      (0, 1)      0         None
# 2      test     drifting      0.333333      (0, 1)      1  yy94AOaczfE
# 3      test     drifting      0.666667      (0, 1)      2  mORdXxZ2uKU
# 4      test     drifting      1.000000      (0, 1)      3  wi33eABMat4
#
#    video_slant                                            recs_id  \
# 0     0.037040  [EWjIL_Thmuk, OLMylqsQew0, SIwvO-DUQNQ, pT8lu9...
# 1          NaN  [jNTVxXrrNS8, Q_sFWhiHxEw, MCZEhOD1CSs, Ly-y7I...
# 2     0.037145  [iVJ94tM7pNA, CFyziP-H6B0, 1ZKBaRsP1gY, fsV-xZ...
# 3     0.279776  [iVJ94tM7pNA, v4H3RY_SoDw, hWxUt41DlB4, uc_SaC...
# 4     0.665696  [i12p_i4-qpM, CVpB8MsIw5A, llOgxVggq4Q, 1ZKBaR...
#
#                                           recs_slant errors    source  \
# 0   [None, None, None, None, None, None, None, None]     []     video
# 1  [0.050350189208984375, 0.5072270631790161, -0....     []  homepage
# 2  [-0.33333, 0.09547054767608643, -0.18236947059...     []     video
# 3  [-0.33333, 0.2996617555618286, -0.088955581188...     []     video
# 4  [0.7287441492080688, 0.34442758560180664, 0.15...     []     video
#
#    watch_time                                             topics
# 0   10.364919                                               None
# 1    0.000000  [All, Podcasts, Armoured fighting vehicle, Rus...
# 2   10.479997                                               None
# 3   10.439081                                               None
# 4   10.312303                                               None
